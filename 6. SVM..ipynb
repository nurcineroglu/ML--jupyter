# %% [markdown]
# # Support Vector Machine (SVM)
# ### Comparison and effects/ Benefits of Normalization/ Standardization

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Checking the columns
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
#Checking for any null values
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#Using One-hot encoding method
dummies = pd.get_dummies(df.diagnosis)
dummies.head()
# Out:
#    B  M
# 0  0  1
# 1  0  1
# 2  0  1
# 3  0  1
# 4  0  1

# %%
data = pd.concat([dummies, df], axis = 1)

# %%
data.head()
# Out:
#    B  M        id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0  0  1    842302         M        17.99         10.38          122.80
# 1  0  1    842517         M        20.57         17.77          132.90
# 2  0  1  84300903         M        19.69         21.25          130.00
# 3  0  1  84348301         M        11.42         20.38           77.58
# 4  0  1  84358402         M        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  ...  texture_worst  \
# 0     1001.0          0.11840           0.27760  ...          17.33
# 1     1326.0          0.08474           0.07864  ...          23.41
# 2     1203.0          0.10960           0.15990  ...          25.53
# 3      386.1          0.14250           0.28390  ...          26.50
# 4     1297.0          0.10030           0.13280  ...          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# ...

# %%
data.drop(['B', 'id', 'diagnosis', 'Unnamed: 32'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    M  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0  1        17.99         10.38          122.80     1001.0          0.11840
# 1  1        20.57         17.77          132.90     1326.0          0.08474
# 2  1        19.69         21.25          130.00     1203.0          0.10960
# 3  1        11.42         20.38           77.58      386.1          0.14250
# 4  1        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  ...  \
# 0           0.27760          0.3001              0.14710         0.2419  ...
# 1           0.07864          0.0869              0.07017         0.1812  ...
# 2           0.15990          0.1974              0.12790         0.2069  ...
# 3           0.28390          0.2414              0.10520         0.2597  ...
# 4           0.13280          0.1980              0.10430         0.1809  ...
#
# ...

# %%
X = data[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
       'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']]

y = data['M']  #This is the dependent variable column

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                test_size=0.3, random_state=101)

# %% [markdown]
# ### Performing SVC Before using Standard Scaler

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
predictions = model.predict(X_test)

# %%
model.score(X, y)
# Out:
# 0.9191564147627417

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[102   3]
#  [ 10  56]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       105
#            1       0.95      0.85      0.90        66
#
#     accuracy                           0.92       171
#    macro avg       0.93      0.91      0.92       171
# weighted avg       0.93      0.92      0.92       171

# %% [markdown]
# ### Performing Standard Scaler to the dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(data.drop('M', axis = 1))
# Out:
# StandardScaler()

# %%
scaled_feature = scaler.transform(data.drop('M', axis = 1))

# %%
scaled_data = pd.DataFrame(scaled_feature, columns = data.columns[1:])

# %%
scaled_data.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
X = scaled_data
y = data['M']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model1 = SVC()

# %%
model1.fit(X_train, y_train)
# Out:
# SVC()

# %%
predictions1 = model1.predict(X_test)

# %%
model1.score(X, y)
# Out:
# 0.9789103690685413

# %%
print(confusion_matrix(y_test, predictions1))
print('\n')
print(classification_report(y_test, predictions1))
# Out:
# [[117   4]
#  [  2  65]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       121
#            1       0.94      0.97      0.96        67
#
#     accuracy                           0.97       188
#    macro avg       0.96      0.97      0.97       188
# weighted avg       0.97      0.97      0.97       188

# %% [markdown]
# ### Performing Grid Search
#
# #### Searching for the best perameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000, 10000], 'gamma': [1,0.1,0.01,0.001,0.0001, 0.00001], 'kernel': ['rbf']}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.623, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.974, total=   0.0s
# ...

# %%
#The best parameter are
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=1000, gamma=0.0001)

# %%
grid_predictions = grid.predict(X_test)

# %%
print(confusion_matrix(y_test, grid_predictions))
print('\n')
print(classification_report(y_test, grid_predictions))
# Out:
# [[119   2]
#  [  2  65]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       121
#            1       0.97      0.97      0.97        67
#
#     accuracy                           0.98       188
#    macro avg       0.98      0.98      0.98       188
# weighted avg       0.98      0.98      0.98       188

# %%
grid.score(X, y)
# Out:
# 0.984182776801406

# %% [markdown]
# ### Thank you!
